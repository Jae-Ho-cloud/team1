# %%
import pandas as pd

df = pd.read_csv('Data\시도별 온실가스 중립도 (2015_2020년).csv', low_memory=False)

df1 = df[df['년도']==2020]
# df1['온실가스흡수량'] = df1['온실가스흡수량'].astype('float64')
df1['온실가스흡수량'] = df1['온실가스흡수량'].astype('int64')
df1
# Out:
# C:\Users\m\AppData\Local\Temp\ipykernel_12636\1530967891.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['온실가스흡수량'] = df1['온실가스흡수량'].astype('int64')
#          시도명    년도    온실가스배출량   온실가스흡수량    온실가스중립도
# 5        강원도  2020   44206196  12880986  29.138418
# 11       경기도  2020   62896148   4858702   7.724960
# 17      경상남도  2020   35581388   6146212  17.273673
# 23      경상북도  2020   50697916  12054970  23.778040
# 29     광주광역시  2020    1443049    189733  13.148065
# 35     대구광역시  2020    3697602    463166  12.526119
# 41     대전광역시  2020    3867799    308284   7.970537
# 47     부산광역시  2020    6787007    349539   5.150122
# 53     서울특별시  2020   12324706    227651   1.847117
# 59   세종특별자치시  2020    2245895    241853  10.768678
# ...

# %%
import pandas as pd

df1['시도명'] = df1['시도명'].replace({
    '강원도': '강원',
    '경기도': '경기',
    '경상남도': '경남',
    '경상북도': '경북',
    '광주광역시': '광주',
    '대구광역시': '대구',
    '대전광역시': '대전',
    '부산광역시': '부산',
    '서울특별시': '서울',
    '세종특별자치시': '세종',
    '울산광역시': '울산',
    '인천광역시': '인천',
    '전라남도': '전남',
    '전라북도': '전북',
    '제주특별자치도': '제주',
    '충청남도': '충남',
    '충청북도': '충북'
})
# Out:
# C:\Users\m\AppData\Local\Temp\ipykernel_12636\2524514515.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['시도명'] = df1['시도명'].replace({

# %%
df1
# Out:
#          시도명    년도    온실가스배출량   온실가스흡수량    온실가스중립도
# 5        강원도  2020   44206196  12880986  29.138418
# 11       경기도  2020   62896148   4858702   7.724960
# 17      경상남도  2020   35581388   6146212  17.273673
# 23      경상북도  2020   50697916  12054970  23.778040
# 29     광주광역시  2020    1443049    189733  13.148065
# 35     대구광역시  2020    3697602    463166  12.526119
# 41     대전광역시  2020    3867799    308284   7.970537
# 47     부산광역시  2020    6787007    349539   5.150122
# 53     서울특별시  2020   12324706    227651   1.847117
# 59   세종특별자치시  2020    2245895    241853  10.768678
# 65     울산광역시  2020   47203696    623523   1.320920
# 71     인천광역시  2020   45126832    369045   0.817796
# 77      전라남도  2020   93199096   6004138   6.442271
# 83      전라북도  2020   13578538   4094161  30.151710
# 89   제주특별자치도  2020    1584366    632021  39.891114
# 95      충청남도  2020  141911600   3563483   2.511059
# 101     충청북도  2020   21256076   4482269  21.087003

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt


font_path = "c:\Windows\Fonts\malgun.ttf"  
font_prop = mpl.font_manager.FontProperties(fname=font_path) 
mpl.rcParams['font.family'] = font_prop.get_name()

df1_sorted1 = df1.sort_values(by='온실가스중립도', ascending=False)

plt.figure(figsize=(17,5))
plt.bar(df1_sorted1['시도명'],df1_sorted1['온실가스중립도'])
plt.title('2020년 시도별 온실가스 중립도')
plt.xlabel('시도명')
plt.ylabel('온실가스 중립도 (%)')
plt.xticks(rotation=45) 
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\m\AppData\Local\Temp\ipykernel_12636\3044492057.py:5: SyntaxWarning: invalid escape sequence '\W'
#   font_path = "c:\Windows\Fonts\malgun.ttf"

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt


font_path = "c:\Windows\Fonts\malgun.ttf"  
font_prop = mpl.font_manager.FontProperties(fname=font_path) 
mpl.rcParams['font.family'] = font_prop.get_name()

df1_sorted2 = df1.sort_values(by='온실가스배출량', ascending=False)

plt.figure(figsize=(17,5))
plt.bar(df1_sorted2['시도명'],df1_sorted2['온실가스배출량'], log=True)
plt.title('2020년 시도별 온실가스 배출량')
plt.xlabel('시도명')
plt.ylabel('온실가스 배출량')
plt.xticks(rotation=45) 
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\m\AppData\Local\Temp\ipykernel_12636\8357387.py:5: SyntaxWarning: invalid escape sequence '\W'
#   font_path = "c:\Windows\Fonts\malgun.ttf"

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt


font_path = "c:\Windows\Fonts\malgun.ttf"  
font_prop = mpl.font_manager.FontProperties(fname=font_path) 
mpl.rcParams['font.family'] = font_prop.get_name()

df1_sorted3 = df1.sort_values(by='온실가스흡수량', ascending=False)

plt.figure(figsize=(17,5))
plt.bar(df1_sorted3['시도명'],df1_sorted3['온실가스흡수량'], log=True)
plt.title('2020년 시도별 온실가스 흡수량')
plt.xlabel('시도명')
plt.ylabel('온실가스 흡수량')
plt.xticks(rotation=45) 
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# <>:5: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\m\AppData\Local\Temp\ipykernel_12636\237863063.py:5: SyntaxWarning: invalid escape sequence '\W'
#   font_path = "c:\Windows\Fonts\malgun.ttf"
