# %% [markdown]
# # [데이터 명세]

# %% [markdown]
# ## [전국 산림 녹지 흡수량 데이터]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 전국 산림 녹지 흡수량 데이터

# %% [markdown]
# ### 2.  수집 데이터 목록
#
# * 시도명, 시군구명, 시군구코드, 기준년도, 전국 침엽수 면적, 전국 활엽수 면적, 전국 혼효림 면적, 전국 침엽수 온실가스 흡수량, 전국 활엽수 온실가스 흡수량, 전국 혼효림 온실가스 흡수량,
#   합계 자연 녹지 온실가스 흡수량, 전국 공원 녹지 면적, 전국 경관 녹지 면적, 전국 연결 녹지 면적, 전국 공원 녹지 온실가스 흡수량, 전국 완충 녹지 온실가스 흡수량, 전국 경관 녹지 온실가스 흡수량,
#   전국 연결 녹지 온실가스 흡수량, 전국 합계 인공녹지 온실가스 흡수량, 전국 합계 온실가스 흡수량

# %% [markdown]
# ### 3.  활용 데이터 목록
#
# * 시도명, 기준년도, 전국 합계 온실가스 흡수량

# %% [markdown]
# ### 4. 수집 방법
#
#
# * 해당 사이트에서 csv 데이터 형태로 수집함 :
# https://www.bigdata-forest.kr/product/ECO100101

# %% [markdown]
# ### 5.   수집 경로
#
# * 산림 빅데이터 거래소 :
# https://www.bigdata-forest.kr/frn/index

# %% [markdown]
#  ![](2023-07-17-15-59-02.png)

# %% [markdown]
# ## [광역시도별 온실가스 배출량 데이터]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 광역시도별 온실가스 배출량 데이터

# %% [markdown]
# ### 2.   수집 데이터 목록
#
#
# * 년도, 광역시도명, 전체온실가스 배출량, 1인당 인구 배출량, 관리업체 1개당 온실가스 배출량

# %% [markdown]
# ### 3.  활용 데이터 목록
#
# * 년도, 광역시도명, 전체 온실가스

# %% [markdown]
# ### 4. 수집 방법

# %% [markdown]
# * 데이터 사이트 접속을 통해 csv 파일 형태로 수집함 :
# https://data.gg.go.kr/portal/data/service/selectServicePage.do?page=1&rows=10&sortColumn=&sortDirection=&infId=OYUMJUDK201TN8I8CM9Y31515663&infSeq=1&order=#none

# %% [markdown]
# ### 5.   수집 경로

# %% [markdown]
# * 경기 데이터 드림 :
# https://data.gg.go.kr/portal/mainPage.do

# %% [markdown]
# ![](2023-07-17-15-59-02.png)

# %% [markdown]
# ## [국가 온실가스 분야별 배출량 추이]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# * 국가 온실가스 분야별 배출량 데이터

# %% [markdown]
# ### 2.   수집 데이터 목록
#
#
# * 연도, 총배출량, 순배출량, 에너지, 산업공정, 농업, 토지이용, 토지이용변화 및 임업, 폐기물

# %% [markdown]
# ### 3.  활용 데이터 목록
#
# * 연도, 총배출량, 순배출량

# %% [markdown]
# ### 4. 수집 방법

# %% [markdown]
# * 데이터 사이트 접속을 통해 csv 파일 형태로 수집함 :
# https://kosis.kr/statHtml/statHtml.do?orgId=106&tblId=DT_106N_99_2800020&vw_cd=MT_ZTITLE&list_id=T_2&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_ZTITLE&path=%252FstatisticsList%252FstatisticsListIndex.do

# %% [markdown]
# ### 5.   수집 경로

# %% [markdown]
# * 국가통계포털 :
# https://kosis.kr/index/index.do
